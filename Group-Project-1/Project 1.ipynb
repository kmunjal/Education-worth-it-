# %%
import pandas as pd
import numpy as np
path="Data Preparation/US_Data_subset.csv"
coarse_data=pd.read_csv(path)

# %%
coarse_data.head()
# Out:
#    Unnamed: 0   FOD1P  SCHL      WAGP  AGEP  COW
# 0           5  6107.0  21.0   39000.0    63  3.0
# 1          23  3600.0  21.0   16000.0    22  2.0
# 2          36  6107.0  21.0  100000.0    52  1.0
# 3          56  3700.0  21.0   41000.0    65  1.0
# 4          92  2300.0  21.0   15000.0    33  1.0

# %%
bachelors_tuition = 24116
masters_tuition = 35000
phd_tuition = 0

coarse_data["tuition"] = np.where(coarse_data.SCHL == 21.0, bachelors_tuition, 
                                  np.where(coarse_data.SCHL == 22.0, masters_tuition, 
                                           np.where(coarse_data.SCHL == 24.0, phd_tuition, "NA")))

coarse_data
# Out:
#          Unnamed: 0   FOD1P  SCHL      WAGP  AGEP  COW tuition
# 0                 5  6107.0  21.0   39000.0    63  3.0   24116
# 1                23  3600.0  21.0   16000.0    22  2.0   24116
# 2                36  6107.0  21.0  100000.0    52  1.0   24116
# 3                56  3700.0  21.0   41000.0    65  1.0   24116
# 4                92  2300.0  21.0   15000.0    33  1.0   24116
# 5                98  6207.0  21.0   20000.0    53  1.0   24116
# 6               102  2414.0  21.0  130000.0    47  1.0   24116
# 7               108  3700.0  22.0   45000.0    36  3.0   35000
# 8               122  3700.0  21.0  104000.0    38  5.0   24116
# 9               125  6107.0  22.0   50000.0    62  2.0   35000
# 10              126  3600.0  23.0  100000.0    62  7.0      NA
# 11              141  5507.0  21.0   40000.0    25  2.0   24116
# 12              145  2300.0  22.0  100000.0    55  5.0   35000
# 13              149  6206.0  21.0       0.0    64  NaN   24116
# ...

# %%
coarse_data.shape

# %%
columns=coarse_data.columns.tolist()

# %%
print(columns)

# %%
df=coarse_data[['FOD1P','SCHL','WAGP','AGEP','COW']]

# %%
df

# %%
df2=df.loc[df['FOD1P']=='NaN'].replace('NaN','Not_that_educated')

# %%
df2.shape

# %%
df2.head()

# %%
df.to_csv("test.csv")
